# %%
import numpy as np
import pandas as pd
from utility.paths import PathList

# %%
raw_annotation = np.load(PathList.luna16_raw_annotation_npy, allow_pickle=True)
raw_annotation
# Out:
# array([{'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860', 'VoxelCoordX': np.int64(45), 'VoxelCoordY': np.int64(211), 'VoxelCoordZ': np.int64(77), 'Diameter': [6.97167141, 6.97167141, 7.34878692, 5.94228451], 'Texture': [5, 5, 5, 5], 'Malignancy': [4, 2, 4, 2], 'Calcification': [6, 6, 6, 6], 'Filename': '1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860_45_211_77_0000.nii.gz'},
#        {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860', 'VoxelCoordX': np.int64(405), 'VoxelCoordY': np.int64(154), 'VoxelCoordZ': np.int64(117), 'Diameter': [4.90860376, 5.31494085, 6.4453125], 'Texture': [5, 5, 4], 'Malignancy': [3, 1, 3], 'Calcification': [6, 6, 6], 'Filename': '1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860_405_154_117_0000.nii.gz'},
# ...
