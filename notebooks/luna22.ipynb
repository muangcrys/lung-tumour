# %%
import SimpleITK as sitk
import numpy as np
import pandas
from pathlib import Path
from luna_dataset.luna22_preprocessing import itk_image_to_numpy_image

# %%
test_img_path = Path(
    r"/LUNA16\niigz\1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860_45_211_77_0000.nii.gz")
annotation_path = Path(r"/LUNA16\annotation.npy")

# %%
test_img_sitk = sitk.ReadImage(test_img_path)
test_img, test_header = itk_image_to_numpy_image(test_img_sitk)

# %%
test_img
# Out:
# array([[[-1024, -1024, -1024, ...,     5,    73,    90],
#         [-1024, -1024, -1024, ...,    21,    71,    86],
#         [-1024, -1024, -1024, ...,    34,    59,    53],
#         ...,
#         [-1024, -1024, -1024, ...,    76,   159,   160],
#         [-1024, -1024, -1024, ...,   -13,    19,    77],
#         [-1024, -1024, -1024, ...,  -108,   -33,    60]],
#
#        [[-1024, -1024, -1024, ...,    65,    23,    11],
#         [-1024, -1024, -1024, ...,    33,    56,   114],
#         [-1024, -1024, -1024, ...,   -25,    49,   139],
#         ...,
#         [-1024, -1024, -1024, ...,   -21,    15,    79],
#         [-1024, -1024, -1024, ...,   -54,    97,   196],
#         [-1024, -1024, -1024, ...,    10,   145,   159]],
#
#        [[-1024, -1024, -1024, ...,    -8,    26,    -2],
#         [-1024, -1024, -1024, ...,   -12,    34,    15],
#         [-1024, -1024, -1024, ...,   -11,    71,   108],
#         ...,
#         [-1024, -1024, -1024, ...,   -11,    18,    58],
# ...

# %%
from matplotlib import pyplot as plt
plt.imshow(test_img[32], cmap='gray')

# %%
annotation = np.load(annotation_path, allow_pickle=True)
annotation[0]
# Out:
# {'SeriesInstanceUID': '1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860',
#  'VoxelCoordX': np.int64(45),
#  'VoxelCoordY': np.int64(211),
#  'VoxelCoordZ': np.int64(77),
#  'Diameter': [6.97167141, 6.97167141, 7.34878692, 5.94228451],
#  'Texture': [5, 5, 5, 5],
#  'Malignancy': [4, 2, 4, 2],
#  'Calcification': [6, 6, 6, 6],
#  'Filename': '1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222365663678666836860_45_211_77_0000.nii.gz'}
