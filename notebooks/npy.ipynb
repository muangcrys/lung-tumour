# %%
import numpy as np
from utility.paths import PathList
from luna_dataset.dataset import LunaDataset
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# %%
train_dataset = LunaDataset.get_dataset_with_transform(split="train", model="random_init")
validate_dataset = LunaDataset.get_dataset_with_transform(split="validate", model="medical_pretrained")
test_dataset = LunaDataset.get_dataset_with_transform(split="test", model="video_pretrained")
# Out:
# No mean or std provided, using default values based on provided statistics: 0.5.
# Mean: [0.5]
# Std: [0.5]
# No mean or std provided, using default values based on provided statistics: 0.5.
# Mean: [0.5]
# Std: [0.5]
# No mean or std provided, using default values based on provided statistics: kinetics.
# Mean: [0.4345, 0.4051, 0.3775]
# Std: [0.2768, 0.2713, 0.2737]

# %%
train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)
validate_dataloader = DataLoader(validate_dataset, batch_size=16, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
train_images, train_labels = next(iter(train_dataloader))
print(train_images.shape, train_labels.shape)
# Out:
# torch.Size([16, 1, 64, 128, 128]) torch.Size([16])

# %%
plt.imshow(train_images[0, 0, 32], cmap='gray')
plt.show()
