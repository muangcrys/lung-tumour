# %%
import numpy as np
from utility.paths import PathList

# %%
t= np.load(PathList.raw_luna_image_dir / "100012_1_19990102.npy")

# %%
t.shape
# Out:
# (64, 128, 128)

# %%
# Out:
# (1, 64, 128, 128)
