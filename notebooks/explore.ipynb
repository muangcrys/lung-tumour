# %%
# # configs
# import tomllib
# from pathlib import Path
# with open(Path.cwd() / "configs.toml", "rb") as config_file:
#     notebook_config = tomllib.load(config_file)
#
# config_path = notebook_config["configs"]["location"]
#
# with open(config_path, "rb") as f:
#     configs = tomllib.load(f)
#
# print(f"Metadata at: {configs['dataset']['metadata']}")
# print(f"Images at: {configs['dataset']['images']}")
# print(f"Annotations at: {configs['dataset']['annotations']}")

from utility.paths import PathList

print(f"Images at: {PathList.raw_luna_image_dir}")
print(f"Annotations at: {PathList.raw_luna_annotation_csv}")
# Out:
# Images at: /Users/muang/Edinburgh/Diss/lung-tumour/data/LUNA/raw/image
# Annotations at: /Users/muang/Edinburgh/Diss/lung-tumour/data/LUNA/raw/annotation/LUNA25_Public_Training_Development_Data.csv

# %%
# annotations
import pandas as pd

annotations_pd = pd.read_csv(PathList.raw_luna_annotation_csv)
annotations_pd.head()
# Out:
#    PatientID                                  SeriesInstanceUID  StudyDate  \
# 0     100570  1.2.840.113654.2.55.32380467633296345717423514...   19990102
# 1     106364  1.2.840.113654.2.55.16930993607533226779708566...   19990102
# 2     127302  1.2.840.113654.2.55.13728437630416839550344528...   20000102
# 3     128899  1.2.840.113654.2.55.40415300708683206534849072...   20010102
# 4     215816  1.3.6.1.4.1.14519.5.2.1.7009.9004.241362276021...   19990102
#
#    CoordX  CoordY  CoordZ  LesionID       AnnotationID  NoduleID  label  \
# 0   61.14 -163.28 -177.75         1  100570_1_19990102  100570_1      1
# 1   30.64  -95.96 -128.59         1  106364_1_19990102  106364_1      1
# 2  -82.53  -27.85 -209.46         1  127302_1_20000102  127302_1      1
# 3  -38.69   -8.78  -39.43         1  128899_1_20010102  128899_1      1
# 4   32.89  -37.98 -100.04         1  215816_1_19990102  215816_1      1
#
#    Age_at_StudyDate  Gender
# 0                63    Male
# ...

# %%
# number of patients
annotations_pd.groupby("PatientID").size()
# Out:
# PatientID
# 100012     2
# 100035     3
# 100069     6
# 100095    12
# 100150     2
#           ..
# 218781     1
# 218817     1
# 218829     3
# 218863     2
# 218866     1
# Length: 2120, dtype: int64

# %%
annotations_pd
# Out:
#       PatientID                                  SeriesInstanceUID  StudyDate  \
# 0        100570  1.2.840.113654.2.55.32380467633296345717423514...   19990102
# 1        106364  1.2.840.113654.2.55.16930993607533226779708566...   19990102
# 2        127302  1.2.840.113654.2.55.13728437630416839550344528...   20000102
# 3        128899  1.2.840.113654.2.55.40415300708683206534849072...   20010102
# 4        215816  1.3.6.1.4.1.14519.5.2.1.7009.9004.241362276021...   19990102
# ...         ...                                                ...        ...
# 6158     123244  1.2.840.113654.2.55.96785330641884045479008848...   20010102
# 6159     104196  1.2.840.113654.2.55.67476228289351741200494264...   20000102
# 6160     104196  1.2.840.113654.2.55.24806580836056963319112187...   20010102
# 6161     204005  1.3.6.1.4.1.14519.5.2.1.7009.9004.291214500058...   19990102
# 6162     204005  1.3.6.1.4.1.14519.5.2.1.7009.9004.204863242782...   20000102
#
# ...

# %%
# patient label the same or not
annotations_pd.groupby("PatientID")["label"].nunique().sort_values()
# Out:
# PatientID
# 100012    1
# 134616    1
# 134612    1
# 134593    1
# 134558    1
#          ..
# 117751    1
# 117737    1
# 117699    1
# 117950    1
# 218866    1
# Name: label, Length: 2120, dtype: int64

# %%
|# number of benign nodules
annotations_pd[annotations_pd["label"] == 0]
# Out:
#   Cell In[6], line 1
#     |# number of benign nodules
#     ^
# SyntaxError: invalid syntax

# %%
annotations_pd[annotations_pd["label"] == 1]
# Out:
#       PatientID                                  SeriesInstanceUID  StudyDate  \
# 0        100570  1.2.840.113654.2.55.32380467633296345717423514...   19990102
# 1        106364  1.2.840.113654.2.55.16930993607533226779708566...   19990102
# 2        127302  1.2.840.113654.2.55.13728437630416839550344528...   20000102
# 3        128899  1.2.840.113654.2.55.40415300708683206534849072...   20010102
# 4        215816  1.3.6.1.4.1.14519.5.2.1.7009.9004.241362276021...   19990102
# ...         ...                                                ...        ...
# 5056     134257  1.2.840.113654.2.55.19134143636557242072696988...   20000102
# 5057     121794  1.2.840.113654.2.55.12380093464274311544899469...   19990102
# 5058     124323  1.2.840.113654.2.55.98593203147463241270004148...   19990102
# 5059     124323  1.2.840.113654.2.55.15295642153836765678497653...   20000102
# 5060     124323  1.2.840.113654.2.55.16466886792267601226886887...   20010102
#
# ...

# %%
# patient level
patients_first_rows = annotations_pd.groupby("PatientID").first()

# %%
patients_first_rows[patients_first_rows["label"] == 0]
# Out:
#                                            SeriesInstanceUID  StudyDate  \
# PatientID
# 100035     1.2.840.113654.2.55.64360087057061878755830205...   19990102
# 100069     1.2.840.113654.2.55.31894721532710462657515245...   20000102
# 100095     1.2.840.113654.2.55.22461859041957100493421265...   19990102
# 100150     1.2.840.113654.2.55.20992147629817300553457726...   20000102
# 100151     1.2.840.113654.2.55.20488740121532740427073763...   19990102
# ...                                                      ...        ...
# 218781     1.3.6.1.4.1.14519.5.2.1.7009.9004.784923545329...   20010102
# 218817     1.3.6.1.4.1.14519.5.2.1.7009.9004.309396145578...   20010102
# 218829     1.3.6.1.4.1.14519.5.2.1.7009.9004.173225373237...   19990102
# 218863     1.3.6.1.4.1.14519.5.2.1.7009.9004.977896926234...   19990102
# 218866     1.3.6.1.4.1.14519.5.2.1.7009.9004.698887010763...   20000102
#
#            CoordX  CoordY   CoordZ  LesionID       AnnotationID  NoduleID  \
# PatientID
# ...

# %%
patients_first_rows[patients_first_rows["label"] == 1]
# Out:
#                                            SeriesInstanceUID  StudyDate  \
# PatientID
# 100012     1.2.840.113654.2.55.24023112856488152536348979...   19990102
# 100560     1.2.840.113654.2.55.17578653928177999534065174...   19990102
# 100570     1.2.840.113654.2.55.32380467633296345717423514...   19990102
# 100619     1.2.840.113654.2.55.29428177947056655991969749...   19990102
# 100703     1.2.840.113654.2.55.25529804576667997729629261...   19990102
# ...                                                      ...        ...
# 217756     1.3.6.1.4.1.14519.5.2.1.7009.9004.210391197267...   20000102
# 217862     1.3.6.1.4.1.14519.5.2.1.7009.9004.196319339638...   19990102
# 218035     1.3.6.1.4.1.14519.5.2.1.7009.9004.138565929432...   19990102
# 218391     1.3.6.1.4.1.14519.5.2.1.7009.9004.163866305568...   19990102
# 218499     1.3.6.1.4.1.14519.5.2.1.7009.9004.174968770387...   19990102
#
#                CoordX      CoordY       CoordZ  LesionID       AnnotationID  \
# PatientID
# ...

# %%
# Secondary characteristics
# males?
males = patients_first_rows[patients_first_rows["Gender"] == "Male"]
males
# Out:
#                                            SeriesInstanceUID  StudyDate  \
# PatientID
# 
# Out:
#                                            SeriesInstanceUID  StudyDate  \
# PatientID
# 100012     1.2.840.113654.2.55.24023112856488152536348979...   19990102
# 100035     1.2.840.113654.2.55.64360087057061878755830205...   19990102
# 100069     1.2.840.113654.2.55.31894721532710462657515245...   20000102
# 100206     1.2.840.113654.2.55.24697903244018314759511100...   20010102
# 100282     1.2.840.113654.2.55.31383051098859272812238832...   20010102
# ...                                                      ...        ...
# 218521     1.3.6.1.4.1.14519.5.2.1.7009.9004.855211409393...   19990102
# 218685     1.3.6.1.4.1.14519.5.2.1.7009.9004.258728945544...   19990102
# 218690     1.3.6.1.4.1.14519.5.2.1.7009.9004.610883885870...   19990102
# 218829     1.3.6.1.4.1.14519.5.2.1.7009.9004.173225373237...   19990102
# 218863     1.3.6.1.4.1.14519.5.2.1.7009.9004.977896926234...   19990102
#
#                CoordX     CoordY       CoordZ  LesionID       AnnotationID  \
# PatientID
# ...

# %%
females[females["label"] == 0]
# Out:
#                                            SeriesInstanceUID  StudyDate  \
# PatientID
# 100035     1.2.840.113654.2.55.64360087057061878755830205...   19990102
# 100069     1.2.840.113654.2.55.31894721532710462657515245...   20000102
# 100206     1.2.840.113654.2.55.24697903244018314759511100...   20010102
# 100282     1.2.840.113654.2.55.31383051098859272812238832...   20010102
# 100440     1.2.840.113654.2.55.84727031191603786551242406...   20000102
# ...                                                      ...        ...
# 218521     1.3.6.1.4.1.14519.5.2.1.7009.9004.855211409393...   19990102
# 218685     1.3.6.1.4.1.14519.5.2.1.7009.9004.258728945544...   19990102
# 218690     1.3.6.1.4.1.14519.5.2.1.7009.9004.610883885870...   19990102
# 218829     1.3.6.1.4.1.14519.5.2.1.7009.9004.173225373237...   19990102
# 218863     1.3.6.1.4.1.14519.5.2.1.7009.9004.977896926234...   19990102
#
#            CoordX  CoordY   CoordZ  LesionID       AnnotationID  NoduleID  \
# PatientID
# ...

# %%
females[females["label"] == 1]
# Out:
#                                            SeriesInstanceUID  StudyDate  \
# PatientID
# 100012     1.2.840.113654.2.55.24023112856488152536348979...   19990102
# 101287     1.2.840.113654.2.55.21448318257051231937749552...   19990102
# 101397     1.2.840.113654.2.55.20093274833398222727010571...   19990102
# 101834     1.2.840.113654.2.55.98360851027786845429916202...   19990102
# 102658     1.2.840.113654.2.55.21379196846380325247937086...   19990102
# ...                                                      ...        ...
# 216238     1.3.6.1.4.1.14519.5.2.1.7009.9004.926070962577...   19990102
# 216370     1.3.6.1.4.1.14519.5.2.1.7009.9004.189765006180...   19990102
# 216940     1.3.6.1.4.1.14519.5.2.1.7009.9004.315936508105...   20000102
# 217465     1.3.6.1.4.1.14519.5.2.1.7009.9004.323969807773...   19990102
# 217482     1.3.6.1.4.1.14519.5.2.1.7009.9004.119783781701...   19990102
#
#               CoordX     CoordY       CoordZ  LesionID       AnnotationID  \
# PatientID
# ...

# %%
from luna_dataset.processing import add_patients_stratifying_key
splitter_pd = add_patients_stratifying_key(annotations_pd.copy())
spd = splitter_pd.groupby("PatientID").nunique()
spd["stratifying_key"].max()
# Out:
# np.int64(1)

# %%
# first item
from luna_dataset.utils import pull_data_raw
first_id = annotations_pd["AnnotationID"].iloc[0]
first_npy = pull_data_raw(first_id)
first_npy.shape
# Out:
# (64, 128, 128)
